# %%
import matplotlib.pyplot as plt
import pandas as pd

data_path = 'data/datasets/KAUST_dataset/raw_data250505_044120'
data_path_2 = 'data/datasets/KAUST_dataset/250505_044124_ros_position_data'

df_1 = pd.read_csv(data_path + '.csv')
df_1 = df_1.interpolate(method='linear')

df_2 = pd.read_csv(data_path_2 + '.csv')
df_2 = df_2.interpolate(method='linear')


plt.plot(df_1['acceleration_x'].values)
plt.plot(df_2['position_x'].values)
plt.show()
